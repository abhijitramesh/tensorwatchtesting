# %%
# %matplotlib notebook
import tensorwatch as tw
client = tw.WatcherClient(filename='test.log')

# %%
s0 = client.open_stream(name='isums')
v0 = tw.Visualizer(stream=s0)
v0.show()
s1 = client.open_stream(name='rsums')
v0 = tw.Visualizer(stream=s1)
v0.show()
# Out:
# [Debug][0]: FileStream started : /Users/abhijitramesh/DeepLearning/Tensorwatch/test.log : t=468.84
# <img src="data:image/png;base64,..." width="800">
# ...
# [Debug][0]: FileStream started : /Users/abhijitramesh/DeepLearning/Tensorwatch/test.log : t=468.87
# <img src="data:image/png;base64,..." width="800">
# ...
